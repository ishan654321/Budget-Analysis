# %% [markdown]
# <a href="https://colab.research.google.com/github/ishan654321/Budget-Analysis/blob/main/PyProject21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install squarify
import squarify

# %%
data = pd.read_csv("/content/India_budget_2021.csv")
data.dropna()
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data = data.iloc[[0, 8, 11, 14, 18, 23, 41, 42, 43], :]

# %%
row = {'Department /Ministry': 'OTHERS', 'Fund allotted(in ₹crores)': 592971.08}
data = data.append(row, ignore_index=True)
# Out:
# <ipython-input-5-00ab11224b2c>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(row, ignore_index=True)

# %%
data = data.sort_values(by='Fund allotted(in ₹crores)', ascending=False)

# %%
data['Fund allotted(in ₹crores)'] = data['Fund allotted(in ₹crores)'].apply(lambda x: "{:,.2f}".format(x))
#apply(lambda x: "{:,.2f}".format(x))
#str.replace(',', '').astype(float)

# %%
data_2023 = pd.read_csv("/content/indan_ budget_ 2023.csv")
data_2023.dropna()
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data_2023 = data_2023.iloc[[0, 8, 11, 14, 18, 23, 41, 42, 43], :]

# %%
row_2023 = {'Department /Ministry': 'OTHERS', 'Fund allotted(in ₹crores)': 592971.08}
data_2023 = data_2023.append(row_2023, ignore_index=True)
# Out:
# <ipython-input-10-a454779f0953>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_2023 = data_2023.append(row_2023, ignore_index=True)

# %%
data_2023 = data_2023.sort_values(by='Fund allotted(in ₹crores)', ascending=False)

# %%
data_2023['Fund allotted(in ₹crores)'] = data_2023['Fund allotted(in ₹crores)'].apply(lambda x: "{:,.2f}".format(x))
#apply(lambda x: "{:,.2f}".format(x))
#str.replace(',', '').astype(float)

# %%
plt.figure(figsize=(12, 6))
plt.bar(data['Department /Ministry'], data['Fund allotted(in ₹crores)'], color='skyblue')
plt.xlabel('Department / Ministry')
plt.ylabel('Fund allotted (in ₹crores)')
plt.title('India Budget 2021 - Department-wise Allocation')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 7))
plt.pie(data['Fund allotted(in ₹crores)'], labels=data['Department /Ministry'], autopct='%1.1f%%', startangle=90, pctdistance=0.85, shadow=True, colors=plt.cm.Paired(np.linspace(0, 1, len(data))))
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.title("Distribution of The Budget", fontsize=20)
plt.legend(data['Department /Ministry'], loc='upper right', bbox_to_anchor=(-0.1, 1.), fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15, 12))
colors = plt.cm.Paired(np.linspace(0, 1, len(data)))
squarify.plot(sizes=data['Fund allotted(in ₹crores)'], label=data['Department /Ministry'], color=colors, alpha=0.7)
plt.axis('off')
plt.title('India Budget 2021 - Department-wise Allocation (TreeMap)')
plt.show()
